# %% [markdown]
# ### Original Dataframe has been split into 2 categories based on Indicator type to make 2 smaller dataframes
# ## Goal: Split the already reduced 2 dataframes further based on Year of INFORM Index column categories

# %% [markdown]
# ### Importing 2 dataframes

# %%
import pandas as pd

# %%
df1 = pd.read_csv("2014-2024 INORM Index.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326248 entries, 0 to 326247
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Iso3            326248 non-null  object
#  1   IndicatorId     326248 non-null  object
#  2   IndicatorName   325091 non-null  object
#  3   IndicatorScore  326248 non-null  float64
#  4   SurveyYear      326248 non-null  int64
#  5   Indicator Type  326248 non-null  object
#  6   INFORMYear      326248 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 17.4+ MB

# %%
df1.head()
# Out:
#   Iso3            IndicatorId                  IndicatorName  IndicatorScore  \
# 0  EST  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
# 1  ETH  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             9.9
# 2  FIN  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
# 3  FJI  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             8.7
# 4  FRA  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
#
#    SurveyYear Indicator Type  INFORMYear
# 0        2021    INORM Index        2024
# 1        2020    INORM Index        2024
# 2        2020    INORM Index        2024
# 3        2020    INORM Index        2024
# 4        2020    INORM Index        2024

# %%
str(len(df1['INFORMYear'].unique()))
# Out:
# '10'

# %%
df2 = pd.read_csv("2014-2024 Core Indicators.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147420 entries, 0 to 147419
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Iso3            147420 non-null  object
#  1   IndicatorId     147420 non-null  object
#  2   IndicatorName   147420 non-null  object
#  3   IndicatorScore  147420 non-null  float64
#  4   SurveyYear      147420 non-null  int64
#  5   Indicator Type  147420 non-null  object
#  6   INFORMYear      147420 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 7.9+ MB

# %%
df2.head()
# Out:
#   Iso3 IndicatorId                                IndicatorName  \
# 0  AFG      AFF_DR  People affected by drought (absolute) - raw
# 1  AGO      AFF_DR  People affected by drought (absolute) - raw
# 2  ALB      AFF_DR  People affected by drought (absolute) - raw
# 3  ARE      AFF_DR  People affected by drought (absolute) - raw
# 4  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#    IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 0   886000.000000        2022  Core Indicators        2024
# 1   197920.457143        2022  Core Indicators        2024
# 2    91428.571429        2022  Core Indicators        2024
# 3        0.000000        2022  Core Indicators        2024
# 4     1000.914286        2022  Core Indicators        2024

# %%
str(len(df2['INFORMYear'].unique()))
# Out:
# '10'

# %% [markdown]
# ### Split each dataframe on Year of INFORM Index (INFORMYear)
# - 10 categories x 2 dataframes
# - Store as (10 x 2) 20 new dataframes
# - Keep original dataframes
# - Export new worksheet for each year dataframes to Project folder

# %% [markdown]
# #### Splitting INFORM Index (df1) by Index Year

# %%
# Grouping by 'INFORM Year'
grouped_df1 = df1.groupby('INFORMYear')

# Creating a dictionary to store DataFrames
df1s = {}

# Splitting and storing DataFrames based on category
for category, group_df1 in grouped_df1:
    df1s[category] = group_df1.copy()

# Accessing the new DataFrames and saving them
for category, new_df in df1s.items():
    print(f"DataFrame of Indeces for INFORM Year {category}:")
    print(new_df.head())
    print()  # line to space between dataframes
    print(new_df.info())
    print()  # line to space between dataframes
    print()  # line to space between dataframes
# Out:
# DataFrame of Indeces for INFORM Year 2015:
#        Iso3 IndicatorId                                 IndicatorName  \
# 293544  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 293545  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 293546  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 293547  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 293548  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 293544        0.568526           0    INORM Index        2015
# 293545        0.468029           0    INORM Index        2015
# 293546        3.170088           0    INORM Index        2015
# 293547        0.000000           0    INORM Index        2015
# 293548        0.000000           0    INORM Index        2015
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32541 entries, 293544 to 326084
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32541 non-null  object
#  1   IndicatorId     32541 non-null  object
#  2   IndicatorName   32422 non-null  object
#  3   IndicatorScore  32541 non-null  float64
#  4   SurveyYear      32541 non-null  int64
#  5   Indicator Type  32541 non-null  object
#  6   INFORMYear      32541 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2016:
#        Iso3 IndicatorId                                 IndicatorName  \
# 260978  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 260979  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 260980  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 260981  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 260982  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 260978        0.551054           0    INORM Index        2016
# 260979        0.451400           0    INORM Index        2016
# 260980        3.171872           0    INORM Index        2016
# 260981        0.000000           0    INORM Index        2016
# 260982        0.000000           0    INORM Index        2016
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32566 entries, 260978 to 293543
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32566 non-null  object
#  1   IndicatorId     32566 non-null  object
#  2   IndicatorName   32445 non-null  object
#  3   IndicatorScore  32566 non-null  float64
#  4   SurveyYear      32566 non-null  int64
#  5   Indicator Type  32566 non-null  object
#  6   INFORMYear      32566 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2017:
#        Iso3 IndicatorId                                 IndicatorName  \
# 228333  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 228334  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 228335  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 228336  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 228337  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 228333        0.537010           0    INORM Index        2017
# 228334        0.435499           0    INORM Index        2017
# 228335        3.173432           0    INORM Index        2017
# 228336        0.000000           0    INORM Index        2017
# 228337        0.000000           0    INORM Index        2017
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32645 entries, 228333 to 260977
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32645 non-null  object
#  1   IndicatorId     32645 non-null  object
#  2   IndicatorName   32525 non-null  object
#  3   IndicatorScore  32645 non-null  float64
#  4   SurveyYear      32645 non-null  int64
#  5   Indicator Type  32645 non-null  object
#  6   INFORMYear      32645 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2018:
#        Iso3 IndicatorId                                 IndicatorName  \
# 195684  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 195685  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 195686  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 195687  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 195688  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 195684        0.521835           0    INORM Index        2018
# 195685        0.412739           0    INORM Index        2018
# 195686        3.175314           0    INORM Index        2018
# 195687        0.000000           0    INORM Index        2018
# 195688        0.000000           0    INORM Index        2018
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32649 entries, 195684 to 228332
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32649 non-null  object
#  1   IndicatorId     32649 non-null  object
#  2   IndicatorName   32537 non-null  object
#  3   IndicatorScore  32649 non-null  float64
#  4   SurveyYear      32649 non-null  int64
#  5   Indicator Type  32649 non-null  object
#  6   INFORMYear      32649 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2019:
#        Iso3 IndicatorId                                 IndicatorName  \
# 163015  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 163016  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 163017  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 163018  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 163019  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 163015        0.506995           0    INORM Index        2019
# 163016        0.528416           0    INORM Index        2019
# 163017        3.177899           0    INORM Index        2019
# 163018        0.000000           0    INORM Index        2019
# 163019        0.000000           0    INORM Index        2019
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32669 entries, 163015 to 195683
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32669 non-null  object
#  1   IndicatorId     32669 non-null  object
#  2   IndicatorName   32555 non-null  object
#  3   IndicatorScore  32669 non-null  float64
#  4   SurveyYear      32669 non-null  int64
#  5   Indicator Type  32669 non-null  object
#  6   INFORMYear      32669 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2020:
#        Iso3 IndicatorId                                 IndicatorName  \
# 130381  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 130382  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 130383  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 130384  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 130385  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#         IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 130381        1.513693           0    INORM Index        2020
# 130382        0.510776           0    INORM Index        2020
# 130383        3.181359           0    INORM Index        2020
# 130384        0.000000           0    INORM Index        2020
# 130385        0.000000           0    INORM Index        2020
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32634 entries, 130381 to 163014
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32634 non-null  object
#  1   IndicatorId     32634 non-null  object
#  2   IndicatorName   32517 non-null  object
#  3   IndicatorScore  32634 non-null  float64
#  4   SurveyYear      32634 non-null  int64
#  5   Indicator Type  32634 non-null  object
#  6   INFORMYear      32634 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2021:
#       Iso3 IndicatorId                                 IndicatorName  \
# 97750  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 97751  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 97752  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 97753  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 97754  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#        IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 97750        1.466979           0    INORM Index        2021
# 97751        0.494352           0    INORM Index        2021
# 97752        3.189167           0    INORM Index        2021
# 97753        0.000000           0    INORM Index        2021
# 97754        0.002222           0    INORM Index        2021
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32631 entries, 97750 to 130380
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32631 non-null  object
#  1   IndicatorId     32631 non-null  object
#  2   IndicatorName   32518 non-null  object
#  3   IndicatorScore  32631 non-null  float64
#  4   SurveyYear      32631 non-null  int64
#  5   Indicator Type  32631 non-null  object
#  6   INFORMYear      32631 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2022:
#       Iso3 IndicatorId                                 IndicatorName  \
# 65103  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 65104  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 65105  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 65106  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 65107  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#        IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 65103        1.425741           0    INORM Index        2022
# 65104        0.573620           0    INORM Index        2022
# 65105        3.202727           0    INORM Index        2022
# 65106        0.000000           0    INORM Index        2022
# 65107        0.002211           0    INORM Index        2022
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32647 entries, 65103 to 97749
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32647 non-null  object
#  1   IndicatorId     32647 non-null  object
#  2   IndicatorName   32533 non-null  object
#  3   IndicatorScore  32647 non-null  float64
#  4   SurveyYear      32647 non-null  int64
#  5   Indicator Type  32647 non-null  object
#  6   INFORMYear      32647 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2023:
#       Iso3 IndicatorId                                 IndicatorName  \
# 32467  AFG  AFF_DR_REL  People affected by droughts (relative) - raw
# 32468  AGO  AFF_DR_REL  People affected by droughts (relative) - raw
# 32469  ALB  AFF_DR_REL  People affected by droughts (relative) - raw
# 32470  ARE  AFF_DR_REL  People affected by droughts (relative) - raw
# 32471  ARG  AFF_DR_REL  People affected by droughts (relative) - raw
#
#        IndicatorScore  SurveyYear Indicator Type  INFORMYear
# 32467        2.154210           0    INORM Index        2023
# 32468        0.556128           0    INORM Index        2023
# 32469        3.216687           0    INORM Index        2023
# 32470        0.000000           0    INORM Index        2023
# 32471        0.002199           0    INORM Index        2023
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32636 entries, 32467 to 65102
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32636 non-null  object
#  1   IndicatorId     32636 non-null  object
#  2   IndicatorName   32522 non-null  object
#  3   IndicatorScore  32636 non-null  float64
#  4   SurveyYear      32636 non-null  int64
#  5   Indicator Type  32636 non-null  object
#  6   INFORMYear      32636 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None
#
#
# DataFrame of Indeces for INFORM Year 2024:
#   Iso3            IndicatorId                  IndicatorName  IndicatorScore  \
# 0  EST  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
# 1  ETH  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             9.9
# 2  FIN  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
# 3  FJI  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             8.7
# 4  FRA  CC.INF.AHC.HEALTH-EXP  Health expenditure per capita             0.0
#
#    SurveyYear Indicator Type  INFORMYear
# 0        2021    INORM Index        2024
# 1        2020    INORM Index        2024
# 2        2020    INORM Index        2024
# 3        2020    INORM Index        2024
# 4        2020    INORM Index        2024
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32630 entries, 0 to 326247
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            32630 non-null  object
#  1   IndicatorId     32630 non-null  object
#  2   IndicatorName   32517 non-null  object
#  3   IndicatorScore  32630 non-null  float64
#  4   SurveyYear      32630 non-null  int64
#  5   Indicator Type  32630 non-null  object
#  6   INFORMYear      32630 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.0+ MB
# None

# %% [markdown]
# #### New INFORM Index Databases/Dataframes created & stored remotely for each Index Year 2015-2024

# %%
import os

# Define the folder path where you want to save the DataFrames
folder_path = '~/Desktop/CodeOp/DSF02/Group Project'  # Replace this with your desired folder path

# Accessing the new DataFrames and saving them
for category, new_df in df1s.items():
    # Construct the file path
    file_path = os.path.join(folder_path, f"INFORM Index {category}.csv")

    # Save each DataFrame as a separate CSV file in the specified folder
    new_df.to_csv(file_path, index=False)
    print(f"DataFrame for Indeces for INFORM Year {category} saved as {file_path}")
# Out:
# DataFrame for Indeces for INFORM Year 2015 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2015.csv
# DataFrame for Indeces for INFORM Year 2016 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2016.csv
# DataFrame for Indeces for INFORM Year 2017 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2017.csv
# DataFrame for Indeces for INFORM Year 2018 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2018.csv
# DataFrame for Indeces for INFORM Year 2019 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2019.csv
# DataFrame for Indeces for INFORM Year 2020 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2020.csv
# DataFrame for Indeces for INFORM Year 2021 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2021.csv
# DataFrame for Indeces for INFORM Year 2022 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2022.csv
# DataFrame for Indeces for INFORM Year 2023 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2023.csv
# DataFrame for Indeces for INFORM Year 2024 saved as ~/Desktop/CodeOp/DSF02/Group Project\INFORM Index 2024.csv

# %% [markdown]
# #### Splitting Core Indicators (df2) by Index Year

# %%
# Grouping by 'INFORM Year'
grouped_df2 = df2.groupby('INFORMYear')

# Creating a dictionary to store DataFrames
df2s = {}

# Splitting and storing DataFrames based on category
for category, group_df2 in grouped_df2:
    df2s[category] = group_df2.copy()

# Accessing the new DataFrames and saving them
for category, new_df2 in df2s.items():
    print(f"DataFrame of Indeces for INFORM Year {category}:")
    print(new_df2.head())
    print()  # line to space between dataframes
    print(new_df2.info())
    print()  # line to space between dataframes
    print()  # line to space between dataframes
# Out:
# DataFrame of Indeces for INFORM Year 2015:
#       Iso3 IndicatorId                                IndicatorName  \
# 73480  AFG      AFF_DR  People affected by drought (absolute) - raw
# 73481  AGO      AFF_DR  People affected by drought (absolute) - raw
# 73482  ALB      AFF_DR  People affected by drought (absolute) - raw
# 73483  ARE      AFF_DR  People affected by drought (absolute) - raw
# 73484  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#        IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 73480   186000.000000        2013  Core Indicators        2015
# 73481   126968.571429        2013  Core Indicators        2015
# 73482    91428.571429        2013  Core Indicators        2015
# 73483        0.000000        2013  Core Indicators        2015
# 73484        0.000000        2013  Core Indicators        2015
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14471 entries, 73480 to 146895
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14471 non-null  object
#  1   IndicatorId     14471 non-null  object
#  2   IndicatorName   14471 non-null  object
#  3   IndicatorScore  14471 non-null  float64
#  4   SurveyYear      14471 non-null  int64
#  5   Indicator Type  14471 non-null  object
#  6   INFORMYear      14471 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 904.4+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2016:
#        Iso3 IndicatorId                                IndicatorName  \
# 117961  AFG      AFF_DR  People affected by drought (absolute) - raw
# 117962  AGO      AFF_DR  People affected by drought (absolute) - raw
# 117963  ALB      AFF_DR  People affected by drought (absolute) - raw
# 117964  ARE      AFF_DR  People affected by drought (absolute) - raw
# 117965  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#         IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 117961   186000.000000        2014  Core Indicators        2016
# 117962   126968.571429        2014  Core Indicators        2016
# 117963    91428.571429        2014  Core Indicators        2016
# 117964        0.000000        2014  Core Indicators        2016
# 117965        0.000000        2014  Core Indicators        2016
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14542 entries, 117961 to 132502
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14542 non-null  object
#  1   IndicatorId     14542 non-null  object
#  2   IndicatorName   14542 non-null  object
#  3   IndicatorScore  14542 non-null  float64
#  4   SurveyYear      14542 non-null  int64
#  5   Indicator Type  14542 non-null  object
#  6   INFORMYear      14542 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 908.9+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2017:
#        Iso3 IndicatorId                                IndicatorName  \
# 103207  AFG      AFF_DR  People affected by drought (absolute) - raw
# 103208  AGO      AFF_DR  People affected by drought (absolute) - raw
# 103209  ALB      AFF_DR  People affected by drought (absolute) - raw
# 103210  ARE      AFF_DR  People affected by drought (absolute) - raw
# 103211  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#         IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 103207   186000.000000        2015  Core Indicators        2017
# 103208   126968.571429        2015  Core Indicators        2017
# 103209    91428.571429        2015  Core Indicators        2017
# 103210        0.000000        2015  Core Indicators        2017
# 103211        0.000000        2015  Core Indicators        2017
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14754 entries, 103207 to 117960
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14754 non-null  object
#  1   IndicatorId     14754 non-null  object
#  2   IndicatorName   14754 non-null  object
#  3   IndicatorScore  14754 non-null  float64
#  4   SurveyYear      14754 non-null  int64
#  5   Indicator Type  14754 non-null  object
#  6   INFORMYear      14754 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 922.1+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2018:
#       Iso3 IndicatorId                                IndicatorName  \
# 88391  AFG      AFF_DR  People affected by drought (absolute) - raw
# 88392  AGO      AFF_DR  People affected by drought (absolute) - raw
# 88393  ALB      AFF_DR  People affected by drought (absolute) - raw
# 88394  ARE      AFF_DR  People affected by drought (absolute) - raw
# 88395  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#        IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 88391   186000.000000        2016  Core Indicators        2018
# 88392   124682.857143        2016  Core Indicators        2018
# 88393    91428.571429        2016  Core Indicators        2018
# 88394        0.000000        2016  Core Indicators        2018
# 88395        0.000000        2016  Core Indicators        2018
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14816 entries, 88391 to 103206
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14816 non-null  object
#  1   IndicatorId     14816 non-null  object
#  2   IndicatorName   14816 non-null  object
#  3   IndicatorScore  14816 non-null  float64
#  4   SurveyYear      14816 non-null  int64
#  5   Indicator Type  14816 non-null  object
#  6   INFORMYear      14816 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 926.0+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2019:
#       Iso3 IndicatorId                                IndicatorName  \
# 73558  AFG      AFF_DR  People affected by drought (absolute) - raw
# 73559  AGO      AFF_DR  People affected by drought (absolute) - raw
# 73560  ALB      AFF_DR  People affected by drought (absolute) - raw
# 73561  ARE      AFF_DR  People affected by drought (absolute) - raw
# 73562  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#        IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 73558   186000.000000        2017  Core Indicators        2019
# 73559   165254.285714        2017  Core Indicators        2019
# 73560    91428.571429        2017  Core Indicators        2019
# 73561        0.000000        2017  Core Indicators        2019
# 73562        0.000000        2017  Core Indicators        2019
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14833 entries, 73558 to 88390
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14833 non-null  object
#  1   IndicatorId     14833 non-null  object
#  2   IndicatorName   14833 non-null  object
#  3   IndicatorScore  14833 non-null  float64
#  4   SurveyYear      14833 non-null  int64
#  5   Indicator Type  14833 non-null  object
#  6   INFORMYear      14833 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 927.1+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2020:
#       Iso3 IndicatorId                                IndicatorName  \
# 43921  AFG      AFF_DR  People affected by drought (absolute) - raw
# 43922  AGO      AFF_DR  People affected by drought (absolute) - raw
# 43923  ALB      AFF_DR  People affected by drought (absolute) - raw
# 43924  ARE      AFF_DR  People affected by drought (absolute) - raw
# 43925  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#        IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 43921   571714.285714        2018  Core Indicators        2020
# 43922   165254.285714        2018  Core Indicators        2020
# 43923    91428.571429        2018  Core Indicators        2020
# 43924        0.000000        2018  Core Indicators        2020
# 43925        0.000000        2018  Core Indicators        2020
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14796 entries, 43921 to 73479
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14796 non-null  object
#  1   IndicatorId     14796 non-null  object
#  2   IndicatorName   14796 non-null  object
#  3   IndicatorScore  14796 non-null  float64
#  4   SurveyYear      14796 non-null  int64
#  5   Indicator Type  14796 non-null  object
#  6   INFORMYear      14796 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 924.8+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2021:
#       Iso3 IndicatorId                                IndicatorName  \
# 29248  AFG      AFF_DR  People affected by drought (absolute) - raw
# 29249  AGO      AFF_DR  People affected by drought (absolute) - raw
# 29250  ALB      AFF_DR  People affected by drought (absolute) - raw
# 29251  ARE      AFF_DR  People affected by drought (absolute) - raw
# 29252  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#        IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 29248   571714.285714        2019  Core Indicators        2021
# 29249   165254.285714        2019  Core Indicators        2021
# 29250    91428.571429        2019  Core Indicators        2021
# 29251        0.000000        2019  Core Indicators        2021
# 29252     1000.914286        2019  Core Indicators        2021
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14797 entries, 29248 to 58748
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14797 non-null  object
#  1   IndicatorId     14797 non-null  object
#  2   IndicatorName   14797 non-null  object
#  3   IndicatorScore  14797 non-null  float64
#  4   SurveyYear      14797 non-null  int64
#  5   Indicator Type  14797 non-null  object
#  6   INFORMYear      14797 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 924.8+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2022:
#     Iso3 IndicatorId                                IndicatorName  \
# 587  AFG      AFF_DR  People affected by drought (absolute) - raw
# 588  AGO      AFF_DR  People affected by drought (absolute) - raw
# 589  ALB      AFF_DR  People affected by drought (absolute) - raw
# 590  ARE      AFF_DR  People affected by drought (absolute) - raw
# 591  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#      IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 587   571714.285714        2020  Core Indicators        2022
# 588   197920.457143        2020  Core Indicators        2022
# 589    91428.571429        2020  Core Indicators        2022
# 590        0.000000        2020  Core Indicators        2022
# 591     1000.914286        2020  Core Indicators        2022
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14812 entries, 587 to 43920
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14812 non-null  object
#  1   IndicatorId     14812 non-null  object
#  2   IndicatorName   14812 non-null  object
#  3   IndicatorScore  14812 non-null  float64
#  4   SurveyYear      14812 non-null  int64
#  5   Indicator Type  14812 non-null  object
#  6   INFORMYear      14812 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 925.8+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2023:
#     Iso3 IndicatorId                                IndicatorName  \
# 382  AFG      AFF_DR  People affected by drought (absolute) - raw
# 383  AGO      AFF_DR  People affected by drought (absolute) - raw
# 384  ALB      AFF_DR  People affected by drought (absolute) - raw
# 385  ARE      AFF_DR  People affected by drought (absolute) - raw
# 386  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#      IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 382   886000.000000        2021  Core Indicators        2023
# 383   197920.457143        2021  Core Indicators        2023
# 384    91428.571429        2021  Core Indicators        2023
# 385        0.000000        2021  Core Indicators        2023
# 386     1000.914286        2021  Core Indicators        2023
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14802 entries, 382 to 29247
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14802 non-null  object
#  1   IndicatorId     14802 non-null  object
#  2   IndicatorName   14802 non-null  object
#  3   IndicatorScore  14802 non-null  float64
#  4   SurveyYear      14802 non-null  int64
#  5   Indicator Type  14802 non-null  object
#  6   INFORMYear      14802 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 925.1+ KB
# None
#
#
# DataFrame of Indeces for INFORM Year 2024:
#   Iso3 IndicatorId                                IndicatorName  \
# 0  AFG      AFF_DR  People affected by drought (absolute) - raw
# 1  AGO      AFF_DR  People affected by drought (absolute) - raw
# 2  ALB      AFF_DR  People affected by drought (absolute) - raw
# 3  ARE      AFF_DR  People affected by drought (absolute) - raw
# 4  ARG      AFF_DR  People affected by drought (absolute) - raw
#
#    IndicatorScore  SurveyYear   Indicator Type  INFORMYear
# 0   886000.000000        2022  Core Indicators        2024
# 1   197920.457143        2022  Core Indicators        2024
# 2    91428.571429        2022  Core Indicators        2024
# 3        0.000000        2022  Core Indicators        2024
# 4     1000.914286        2022  Core Indicators        2024
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 14797 entries, 0 to 147419
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Iso3            14797 non-null  object
#  1   IndicatorId     14797 non-null  object
#  2   IndicatorName   14797 non-null  object
#  3   IndicatorScore  14797 non-null  float64
#  4   SurveyYear      14797 non-null  int64
#  5   Indicator Type  14797 non-null  object
#  6   INFORMYear      14797 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 924.8+ KB
# None

# %% [markdown]
# #### New Core Indicators Databases/Dataframes created & stored remotely for each Index Year 2015-2024

# %%
# Define the folder path where you want to save the DataFrames
folder_path = '~/Desktop/CodeOp/DSF02/Group Project'  # Replace this with your desired folder path

# Accessing the new DataFrames and saving them
for category, new_df2 in df2s.items():
    # Construct the file path
    file_path = os.path.join(folder_path, f"Core Indicators {category}.csv")

    # Save each DataFrame as a separate CSV file in the specified folder
    new_df2.to_csv(file_path, index=False)
    print(f"DataFrame for Core Indicators for INFORM Year {category} saved as {file_path}")
# Out:
# DataFrame for Core Indicators for INFORM Year 2015 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2015.csv
# DataFrame for Core Indicators for INFORM Year 2016 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2016.csv
# DataFrame for Core Indicators for INFORM Year 2017 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2017.csv
# DataFrame for Core Indicators for INFORM Year 2018 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2018.csv
# DataFrame for Core Indicators for INFORM Year 2019 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2019.csv
# DataFrame for Core Indicators for INFORM Year 2020 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2020.csv
# DataFrame for Core Indicators for INFORM Year 2021 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2021.csv
# DataFrame for Core Indicators for INFORM Year 2022 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2022.csv
# DataFrame for Core Indicators for INFORM Year 2023 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2023.csv
# DataFrame for Core Indicators for INFORM Year 2024 saved as ~/Desktop/CodeOp/DSF02/Group Project\Core Indicators 2024.csv
