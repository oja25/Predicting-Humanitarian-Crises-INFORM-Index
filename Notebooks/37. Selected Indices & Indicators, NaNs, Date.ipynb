# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime , calendar
import statistics as st
import math

import os

# %%
df = pd.read_csv("2015-2024_59 Selected Index Indicator df.csv")

# %%
pd.set_option('display.max_columns', None) # to show more columns than default 20, could input a number instead of None
pd.set_option('display.max_rows', None) # to show more rows than default 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1910 entries, 0 to 1909
# Data columns (total 62 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   COUNTRY                                                                1910 non-null   object
#  1   Iso3                                                                   1910 non-null   object
#  2   INFORMYear                                                             1910 non-null   int64
#  3   % of Populations at risk of Plasmodium falciparum malaria              1910 non-null   float64
#  4   Access to Health Care                                                  1900 non-null   float64
#  5   Access to electricity                                                  1910 non-null   float64
# ...

# %% [markdown]
# - 4   Access to Health Care                                                  1900 non-null   float64
# - 7   Adult literacy rate                                                    1556 non-null   float64
# - 8   Adult prevalence of HIV-AIDS                                           1490 non-null   float64
# - 10  Corruption Perception Index                                            1773 non-null   float64
# - 11  GDP per capita                                                         1883 non-null   float64
# - 12  Gender Inequality Index                                                1694 non-null   float64
# - 17  Health expenditure per capita                                          1866 non-null   float64
# - 23  Inequality                                                             1807 non-null   float64
# - 25  Internet users                                                         1902 non-null   float64
# - 27  Literacy rate, adult total                                             1556 non-null   float64
# - 28  Maternal Mortality Ratio                                               1840 non-null   float64
# - 30  Multidimensional Poverty Index                                         1157 non-null   float64
# - 33  Palestinian Refugees                                                   40 non-null     float64
# - 36  Personal remittances, received (% of GDP)                              1817 non-null   float64
# - 38  Physicians density                                                     1883 non-null   float64
# - 55  Under-five mortality rate                                              1900 non-null   float64
# - 57  Vets per capita                                                        1825 non-null   float64
# - 59  Volume of remittances                                                  1817 non-null   float64

# %% [markdown]
# #prints all, but not very useful
# #columns_with_null = df.columns[df.isna().any()].tolist()
# #df_with_null = df[columns_with_null]
#
# #print(df_with_null)
#
# #prints all, but not very useful
# #columns_count_null = df.columns[df.isna().sum()>0].tolist()
# #df_sum_null = df[columns_count_null]
#
# #print(df_sum_null)
#
# #same as above
# #columns_count_null = df.columns[df.isna().count() > 0].tolist()
# #df_count_null = df[columns_count_null]
#
# #print(df_count_null)

# %%
null_counts = df.isna().sum()

for column, null_count in null_counts.items():
    if null_count > 0:
        print(f"Column '{column}' has {null_count} null values")
# Out:
# Column 'Access to Health Care' has 10 null values
# Column 'Adult literacy rate' has 354 null values
# Column 'Adult prevalence of HIV-AIDS' has 420 null values
# Column 'Corruption Perception Index' has 137 null values
# Column 'GDP per capita' has 27 null values
# Column 'Gender Inequality Index' has 216 null values
# Column 'Health expenditure per capita' has 44 null values
# Column 'Inequality' has 103 null values
# Column 'Internet users' has 8 null values
# Column 'Literacy rate, adult total' has 354 null values
# Column 'Maternal Mortality Ratio' has 70 null values
# Column 'Multidimensional Poverty Index' has 753 null values
# Column 'Palestinian Refugees' has 1870 null values
# Column 'Personal remittances, received (% of GDP)' has 93 null values
# Column 'Physicians density' has 27 null values
# Column 'Population living in slums (% of urban population)' has 894 null values
# Column 'Under-five mortality rate' has 10 null values
# ...

# %%
# Filter the DataFrame to select rows where specific columns have null values
rows_with_null_values = df[df['Access to Health Care'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#            COUNTRY  INFORMYear
# 990  Liechtenstein        2015
# 991  Liechtenstein        2016
# 992  Liechtenstein        2017
# 993  Liechtenstein        2018
# 994  Liechtenstein        2019
# 995  Liechtenstein        2020
# 996  Liechtenstein        2021
# 997  Liechtenstein        2022
# 998  Liechtenstein        2023
# 999  Liechtenstein        2024

# %%
rows_with_null_values = df[df['Adult literacy rate'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                                COUNTRY  INFORMYear
# 70                           Australia        2015
# 71                           Australia        2016
# 72                           Australia        2017
# 73                           Australia        2018
# 74                           Australia        2019
# 75                           Australia        2020
# 76                           Australia        2021
# 77                           Australia        2022
# 78                           Australia        2023
# 79                           Australia        2024
# 80                             Austria        2015
# 81                             Austria        2016
# 82                             Austria        2017
# 83                             Austria        2018
# 84                             Austria        2019
# 85                             Austria        2020
# 86                             Austria        2021
# ...

# %%
latest_fill = df[(df['COUNTRY'] == "Belize") & (df['INFORMYear'] == 2016)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Belize") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Czech Republic") & (df['INFORMYear'] == 2017)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Czech Republic") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Fiji") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Fiji") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Libya") & (df['INFORMYear'] == 2019)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Libya") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Myanmar") & (df['INFORMYear'] == 2017)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Myanmar") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Yemen") & (df['INFORMYear'] == 2019)]
to_fill = latest_fill['Adult literacy rate'].iloc[0]
df.loc[(df['COUNTRY'] == "Yemen") & (df['Adult literacy rate'].isna()), 'Adult literacy rate'] = to_fill

# %%
rows_with_null_values = df[df['Adult literacy rate'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                                COUNTRY  INFORMYear
# 70                           Australia        2015
# 71                           Australia        2016
# 72                           Australia        2017
# 73                           Australia        2018
# 74                           Australia        2019
# 75                           Australia        2020
# 76                           Australia        2021
# 77                           Australia        2022
# 78                           Australia        2023
# 79                           Australia        2024
# 80                             Austria        2015
# 81                             Austria        2016
# 82                             Austria        2017
# 83                             Austria        2018
# 84                             Austria        2019
# 85                             Austria        2020
# 86                             Austria        2021
# ...

# %%
rows_with_null_values = df[df['GDP per capita'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#           COUNTRY  INFORMYear
# 510       Eritrea        2015
# 511       Eritrea        2016
# 512       Eritrea        2017
# 513       Eritrea        2018
# 514       Eritrea        2019
# 515       Eritrea        2020
# 516       Eritrea        2021
# 517       Eritrea        2022
# 518       Eritrea        2023
# 519       Eritrea        2024
# 1562  South Sudan        2017
# 1563  South Sudan        2018
# 1564  South Sudan        2019
# 1565  South Sudan        2020
# 1566  South Sudan        2021
# 1567  South Sudan        2022
# 1568  South Sudan        2023
# 1569  South Sudan        2024
# 1831    Venezuela        2016
# 1832    Venezuela        2017
# 1833    Venezuela        2018
# 1834    Venezuela        2019
# 1835    Venezuela        2020
# 1836    Venezuela        2021
# 1837    Venezuela        2022
# 1838    Venezuela        2023
# 1839    Venezuela        2024

# %%
rows_with_null_values = df[df['Health expenditure per capita'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#             COUNTRY  INFORMYear
# 979           Libya        2024
# 990   Liechtenstein        2015
# 991   Liechtenstein        2016
# 992   Liechtenstein        2017
# 993   Liechtenstein        2018
# 994   Liechtenstein        2019
# 995   Liechtenstein        2020
# 996   Liechtenstein        2021
# 997   Liechtenstein        2022
# 998   Liechtenstein        2023
# 999   Liechtenstein        2024
# 1390      Korea DPR        2015
# 1391      Korea DPR        2016
# 1392      Korea DPR        2017
# 1393      Korea DPR        2018
# 1394      Korea DPR        2019
# 1395      Korea DPR        2020
# 1396      Korea DPR        2021
# 1397      Korea DPR        2022
# 1398      Korea DPR        2023
# 1399      Korea DPR        2024
# 1420      Palestine        2015
# 1421      Palestine        2016
# 1422      Palestine        2017
# 1423      Palestine        2018
# 1424      Palestine        2019
# 1425      Palestine        2020
# 1426      Palestine        2021
# ...

# %%
# Filter DataFrame to select rows where 'COUNTRY' is "Libya" and 'INFORMYear' is 2023
latest_fill = df[(df['COUNTRY'] == "Libya") & (df['INFORMYear'] == 2023)]

# Get the value for 'Health expenditure per capita' from the filtered DataFrame
to_fill = latest_fill['Health expenditure per capita'].iloc[0]

# Fill NaN values in 'Health expenditure per capita' column with the value from 2023 for Libya
df.loc[(df['COUNTRY'] == "Libya") & (df['Health expenditure per capita'].isna()), 'Health expenditure per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "South Sudan") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Health expenditure per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "South Sudan") & (df['Health expenditure per capita'].isna()), 'Health expenditure per capita'] = to_fill

# %%
rows_with_null_values = df[df['Health expenditure per capita'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#             COUNTRY  INFORMYear
# 990   Liechtenstein        2015
# 991   Liechtenstein        2016
# 992   Liechtenstein        2017
# 993   Liechtenstein        2018
# 994   Liechtenstein        2019
# 995   Liechtenstein        2020
# 996   Liechtenstein        2021
# 997   Liechtenstein        2022
# 998   Liechtenstein        2023
# 999   Liechtenstein        2024
# 1390      Korea DPR        2015
# 1391      Korea DPR        2016
# 1392      Korea DPR        2017
# 1393      Korea DPR        2018
# 1394      Korea DPR        2019
# 1395      Korea DPR        2020
# 1396      Korea DPR        2021
# 1397      Korea DPR        2022
# 1398      Korea DPR        2023
# 1399      Korea DPR        2024
# 1420      Palestine        2015
# 1421      Palestine        2016
# 1422      Palestine        2017
# 1423      Palestine        2018
# 1424      Palestine        2019
# 1425      Palestine        2020
# 1426      Palestine        2021
# 1427      Palestine        2022
# ...

# %%
rows_with_null_values = df[df['Internet users'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#      COUNTRY  INFORMYear
# 1362   Palau        2017
# 1363   Palau        2018
# 1364   Palau        2019
# 1365   Palau        2020
# 1366   Palau        2021
# 1367   Palau        2022
# 1368   Palau        2023
# 1369   Palau        2024

# %%
rows_with_null_values = df[df['Maternal Mortality Ratio'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                     COUNTRY  INFORMYear
# 450                Dominica        2015
# 451                Dominica        2016
# 452                Dominica        2017
# 453                Dominica        2018
# 454                Dominica        2019
# 455                Dominica        2020
# 456                Dominica        2021
# 457                Dominica        2022
# 458                Dominica        2023
# 459                Dominica        2024
# 910   Saint Kitts and Nevis        2015
# 911   Saint Kitts and Nevis        2016
# 912   Saint Kitts and Nevis        2017
# 913   Saint Kitts and Nevis        2018
# 914   Saint Kitts and Nevis        2019
# 915   Saint Kitts and Nevis        2020
# 916   Saint Kitts and Nevis        2021
# 917   Saint Kitts and Nevis        2022
# 918   Saint Kitts and Nevis        2023
# 919   Saint Kitts and Nevis        2024
# 990           Liechtenstein        2015
# 991           Liechtenstein        2016
# ...

# %%
rows_with_null_values = df[df['Inequality'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                                COUNTRY  INFORMYear
# 60                 Antigua and Barbuda        2015
# 61                 Antigua and Barbuda        2016
# 62                 Antigua and Barbuda        2017
# 63                 Antigua and Barbuda        2018
# 64                 Antigua and Barbuda        2019
# 65                 Antigua and Barbuda        2020
# 66                 Antigua and Barbuda        2021
# 67                 Antigua and Barbuda        2022
# 68                 Antigua and Barbuda        2023
# 69                 Antigua and Barbuda        2024
# 240                  Brunei Darussalam        2015
# 241                  Brunei Darussalam        2016
# 450                           Dominica        2015
# 451                           Dominica        2016
# 452                           Dominica        2017
# 453                           Dominica        2018
# 454                           Dominica        2019
# ...

# %%
latest_fill = df[(df['COUNTRY'] == "Brunei Darussalam") & (df['INFORMYear'] == 2017)]
to_fill = latest_fill['Inequality'].iloc[0]
df.loc[(df['COUNTRY'] == "Brunei Darussalam") & (df['Inequality'].isna()), 'Inequality'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Marshall Islands") & (df['INFORMYear'] == 2020)]
to_fill = latest_fill['Inequality'].iloc[0]
df.loc[(df['COUNTRY'] == "Marshall Islands") & (df['Inequality'].isna()), 'Inequality'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Somalia") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Inequality'].iloc[0]
df.loc[(df['COUNTRY'] == "Somalia") & (df['Inequality'].isna()), 'Inequality'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Saint Vincent and the Grenadines") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Inequality'].iloc[0]
df.loc[(df['COUNTRY'] == "Saint Vincent and the Grenadines") & (df['Inequality'].isna()), 'Inequality'] = to_fill

# %%
rows_with_null_values = df[df['Inequality'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                     COUNTRY  INFORMYear
# 60      Antigua and Barbuda        2015
# 61      Antigua and Barbuda        2016
# 62      Antigua and Barbuda        2017
# 63      Antigua and Barbuda        2018
# 64      Antigua and Barbuda        2019
# 65      Antigua and Barbuda        2020
# 66      Antigua and Barbuda        2021
# 67      Antigua and Barbuda        2022
# 68      Antigua and Barbuda        2023
# 69      Antigua and Barbuda        2024
# 450                Dominica        2015
# 451                Dominica        2016
# 452                Dominica        2017
# 453                Dominica        2018
# 454                Dominica        2019
# 455                Dominica        2020
# 456                Dominica        2021
# 457                Dominica        2022
# 458                Dominica        2023
# 459                Dominica        2024
# 510                 Eritrea        2015
# 511                 Eritrea        2016
# ...

# %%
#Countries with Palestinian Refugees - all other cells should be rest to 0
no_null_values = df[df['Palestinian Refugees'].notna()]
print(no_null_values[['COUNTRY','INFORMYear']])
# Out:
#         COUNTRY  INFORMYear
# 840      Jordan        2015
# 841      Jordan        2016
# 842      Jordan        2017
# 843      Jordan        2018
# 844      Jordan        2019
# 845      Jordan        2020
# 846      Jordan        2021
# 847      Jordan        2022
# 848      Jordan        2023
# 849      Jordan        2024
# 950     Lebanon        2015
# 951     Lebanon        2016
# 952     Lebanon        2017
# 953     Lebanon        2018
# 954     Lebanon        2019
# 955     Lebanon        2020
# 956     Lebanon        2021
# 957     Lebanon        2022
# 958     Lebanon        2023
# 959     Lebanon        2024
# 1420  Palestine        2015
# 1421  Palestine        2016
# 1422  Palestine        2017
# 1423  Palestine        2018
# 1424  Palestine        2019
# 1425  Palestine        2020
# 1426  Palestine        2021
# 1427  Palestine        2022
# 1428  Palestine        2023
# 1429  Palestine        2024
# 1640      Syria        2015
# 1641      Syria        2016
# ...

# %%
# Fill null values with 0 in the 'Palestinian refugees' column
df['Palestinian Refugees'].fillna(0, inplace=True)

# %%
#Countries with Palestinian Refugees - all other cells should now have a value
rows_with_null_values = df[df['Palestinian Refugees'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
# Empty DataFrame
# Columns: [COUNTRY, INFORMYear]
# Index: []

# %%
rows_with_null_values = df[df['Personal remittances, received (% of GDP)'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                    COUNTRY  INFORMYear
# 30    United Arab Emirates        2015
# 31    United Arab Emirates        2016
# 32    United Arab Emirates        2017
# 33    United Arab Emirates        2018
# 34    United Arab Emirates        2019
# 35    United Arab Emirates        2020
# 36    United Arab Emirates        2021
# 37    United Arab Emirates        2022
# 38    United Arab Emirates        2023
# 39    United Arab Emirates        2024
# 160                Bahrain        2015
# 161                Bahrain        2016
# 162                Bahrain        2017
# 163                Bahrain        2018
# 164                Bahrain        2019
# 165                Bahrain        2020
# 166                Bahrain        2021
# 167                Bahrain        2022
# 168                Bahrain        2023
# 169                Bahrain        2024
# 170                Bahamas        2015
# 171                Bahamas        2016
# 172                Bahamas        2017
# ...

# %%
latest_fill = df[(df['COUNTRY'] == "Brunei Darussalam") & (df['INFORMYear'] == 2021)]
to_fill = latest_fill['Personal remittances, received (% of GDP)'].iloc[0]
df.loc[(df['COUNTRY'] == "Brunei Darussalam") & (df['Personal remittances, received (% of GDP)'].isna()), 'Personal remittances, received (% of GDP)'] = to_fill

# %%
rows_with_null_values = df[df['Personal remittances, received (% of GDP)'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                    COUNTRY  INFORMYear
# 30    United Arab Emirates        2015
# 31    United Arab Emirates        2016
# 32    United Arab Emirates        2017
# 33    United Arab Emirates        2018
# 34    United Arab Emirates        2019
# 35    United Arab Emirates        2020
# 36    United Arab Emirates        2021
# 37    United Arab Emirates        2022
# 38    United Arab Emirates        2023
# 39    United Arab Emirates        2024
# 160                Bahrain        2015
# 161                Bahrain        2016
# 162                Bahrain        2017
# 163                Bahrain        2018
# 164                Bahrain        2019
# 165                Bahrain        2020
# 166                Bahrain        2021
# 167                Bahrain        2022
# 168                Bahrain        2023
# 169                Bahrain        2024
# 170                Bahamas        2015
# 171                Bahamas        2016
# 172                Bahamas        2017
# ...

# %%
rows_with_null_values = df[df['Physicians density'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#             COUNTRY  INFORMYear
# 451        Dominica        2016
# 452        Dominica        2017
# 990   Liechtenstein        2015
# 991   Liechtenstein        2016
# 992   Liechtenstein        2017
# 993   Liechtenstein        2018
# 994   Liechtenstein        2019
# 995   Liechtenstein        2020
# 996   Liechtenstein        2021
# 997   Liechtenstein        2022
# 998   Liechtenstein        2023
# 999   Liechtenstein        2024
# 1421      Palestine        2016
# 1422      Palestine        2017
# 1423      Palestine        2018
# 1424      Palestine        2019
# 1425      Palestine        2020
# 1426      Palestine        2021
# 1427      Palestine        2022
# 1428      Palestine        2023
# 1429      Palestine        2024
# 1560    South Sudan        2015
# 1561    South Sudan        2016
# 1562    South Sudan        2017
# 1563    South Sudan        2018
# 1831      Venezuela        2016
# 1832      Venezuela        2017

# %%
latest_fill = df[(df['COUNTRY'] == "Dominica") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Physicians density'].iloc[0]
df.loc[(df['COUNTRY'] == "Dominica") & (df['Physicians density'].isna()), 'Physicians density'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "South Sudan") & (df['INFORMYear'] == 2019)]
to_fill = latest_fill['Physicians density'].iloc[0]
df.loc[(df['COUNTRY'] == "South Sudan") & (df['Physicians density'].isna()), 'Physicians density'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Venezuela") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Physicians density'].iloc[0]
df.loc[(df['COUNTRY'] == "Venezuela") & (df['Physicians density'].isna()), 'Physicians density'] = to_fill

# %%
rows_with_null_values = df[df['Physicians density'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#             COUNTRY  INFORMYear
# 990   Liechtenstein        2015
# 991   Liechtenstein        2016
# 992   Liechtenstein        2017
# 993   Liechtenstein        2018
# 994   Liechtenstein        2019
# 995   Liechtenstein        2020
# 996   Liechtenstein        2021
# 997   Liechtenstein        2022
# 998   Liechtenstein        2023
# 999   Liechtenstein        2024
# 1421      Palestine        2016
# 1422      Palestine        2017
# 1423      Palestine        2018
# 1424      Palestine        2019
# 1425      Palestine        2020
# 1426      Palestine        2021
# 1427      Palestine        2022
# 1428      Palestine        2023
# 1429      Palestine        2024

# %%
rows_with_null_values = df[df['Under-five mortality rate'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#            COUNTRY  INFORMYear
# 990  Liechtenstein        2015
# 991  Liechtenstein        2016
# 992  Liechtenstein        2017
# 993  Liechtenstein        2018
# 994  Liechtenstein        2019
# 995  Liechtenstein        2020
# 996  Liechtenstein        2021
# 997  Liechtenstein        2022
# 998  Liechtenstein        2023
# 999  Liechtenstein        2024

# %%
rows_with_null_values = df[df['Vets per capita'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                     COUNTRY  INFORMYear
# 60      Antigua and Barbuda        2015
# 61      Antigua and Barbuda        2016
# 62      Antigua and Barbuda        2017
# 63      Antigua and Barbuda        2018
# 64      Antigua and Barbuda        2019
# 65      Antigua and Barbuda        2020
# 66      Antigua and Barbuda        2021
# 67      Antigua and Barbuda        2022
# 68      Antigua and Barbuda        2023
# 69      Antigua and Barbuda        2024
# 170                 Bahamas        2015
# 450                Dominica        2015
# 451                Dominica        2016
# 452                Dominica        2017
# 453                Dominica        2018
# 454                Dominica        2019
# 455                Dominica        2020
# 456                Dominica        2021
# 457                Dominica        2022
# 458                Dominica        2023
# 459                Dominica        2024
# 640                  Gambia        2015
# ...

# %%
latest_fill = df[(df['COUNTRY'] == "Bahamas") & (df['INFORMYear'] == 2016)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "Bahamas") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Gambia") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "Gambia") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Saint Kitts and Nevis") & (df['INFORMYear'] == 2022)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "Saint Kitts and Nevis") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Saint Lucia") & (df['INFORMYear'] == 2019)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "Saint Lucia") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Russian Federation") & (df['INFORMYear'] == 2018)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "Russian Federation") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "South Sudan") & (df['INFORMYear'] == 2017)]
to_fill = latest_fill['Vets per capita'].iloc[0]
df.loc[(df['COUNTRY'] == "South Sudan") & (df['Vets per capita'].isna()), 'Vets per capita'] = to_fill

# %%
rows_with_null_values = df[df['Vets per capita'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                   COUNTRY  INFORMYear
# 60    Antigua and Barbuda        2015
# 61    Antigua and Barbuda        2016
# 62    Antigua and Barbuda        2017
# 63    Antigua and Barbuda        2018
# 64    Antigua and Barbuda        2019
# 65    Antigua and Barbuda        2020
# 66    Antigua and Barbuda        2021
# 67    Antigua and Barbuda        2022
# 68    Antigua and Barbuda        2023
# 69    Antigua and Barbuda        2024
# 450              Dominica        2015
# 451              Dominica        2016
# 452              Dominica        2017
# 453              Dominica        2018
# 454              Dominica        2019
# 455              Dominica        2020
# 456              Dominica        2021
# 457              Dominica        2022
# 458              Dominica        2023
# 459              Dominica        2024
# 680               Grenada        2015
# 681               Grenada        2016
# 682               Grenada        2017
# 683               Grenada        2018
# ...

# %%
rows_with_null_values = df[df['Volume of remittances'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                    COUNTRY  INFORMYear
# 30    United Arab Emirates        2015
# 31    United Arab Emirates        2016
# 32    United Arab Emirates        2017
# 33    United Arab Emirates        2018
# 34    United Arab Emirates        2019
# 35    United Arab Emirates        2020
# 36    United Arab Emirates        2021
# 37    United Arab Emirates        2022
# 38    United Arab Emirates        2023
# 39    United Arab Emirates        2024
# 160                Bahrain        2015
# 161                Bahrain        2016
# 162                Bahrain        2017
# 163                Bahrain        2018
# 164                Bahrain        2019
# 165                Bahrain        2020
# 166                Bahrain        2021
# 167                Bahrain        2022
# 168                Bahrain        2023
# 169                Bahrain        2024
# 170                Bahamas        2015
# 171                Bahamas        2016
# 172                Bahamas        2017
# ...

# %%
latest_fill = df[(df['COUNTRY'] == "Brunei Darussalam") & (df['INFORMYear'] == 2021)]
to_fill = latest_fill['Volume of remittances'].iloc[0]
df.loc[(df['COUNTRY'] == "Brunei Darussalam") & (df['Volume of remittances'].isna()), 'Volume of remittances'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "South Sudan") & (df['INFORMYear'] == 2016)]
to_fill = latest_fill['Volume of remittances'].iloc[0]
df.loc[(df['COUNTRY'] == "South Sudan") & (df['Volume of remittances'].isna()), 'Volume of remittances'] = to_fill

# %%
latest_fill = df[(df['COUNTRY'] == "Venezuela") & (df['INFORMYear'] == 2015)]
to_fill = latest_fill['Volume of remittances'].iloc[0]
df.loc[(df['COUNTRY'] == "Venezuela") & (df['Volume of remittances'].isna()), 'Volume of remittances'] = to_fill

# %%
rows_with_null_values = df[df['Volume of remittances'].isna()]
print(rows_with_null_values[['COUNTRY','INFORMYear']])
# Out:
#                    COUNTRY  INFORMYear
# 30    United Arab Emirates        2015
# 31    United Arab Emirates        2016
# 32    United Arab Emirates        2017
# 33    United Arab Emirates        2018
# 34    United Arab Emirates        2019
# 35    United Arab Emirates        2020
# 36    United Arab Emirates        2021
# 37    United Arab Emirates        2022
# 38    United Arab Emirates        2023
# 39    United Arab Emirates        2024
# 160                Bahrain        2015
# 161                Bahrain        2016
# 162                Bahrain        2017
# 163                Bahrain        2018
# 164                Bahrain        2019
# 165                Bahrain        2020
# 166                Bahrain        2021
# 167                Bahrain        2022
# 168                Bahrain        2023
# 169                Bahrain        2024
# 170                Bahamas        2015
# 171                Bahamas        2016
# 172                Bahamas        2017
# ...

# %%
# Calculate the column averages for numeric columns
column_averages = df.select_dtypes(include=['float']).mean()

# Fill null values with column averages
df_filled = df.fillna(column_averages)

# %%
df_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1910 entries, 0 to 1909
# Data columns (total 62 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   COUNTRY                                                                1910 non-null   object
#  1   Iso3                                                                   1910 non-null   object
#  2   INFORMYear                                                             1910 non-null   int64
#  3   % of Populations at risk of Plasmodium falciparum malaria              1910 non-null   float64
#  4   Access to Health Care                                                  1910 non-null   float64
#  5   Access to electricity                                                  1910 non-null   float64
# ...

# %%
# Define the folder path where you want to save the DataFrames
folder_path = '~/Desktop/CodeOp/DSF02/Group Project'

# Construct the file path
file_path = os.path.join(folder_path, f"2015-2024_df_INFORM_index_core_indicators.csv")

# Save each DataFrame as a separate CSV file in the specified folder
df_filled.to_csv(file_path, index=False)
