# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime , calendar
import statistics as st
import math

import os

# %%
df = pd.read_csv("2015-2024_df_INFORM_index_core_indicators.csv", index_col = 'INFORMYear', parse_dates=True)
df.head()
# Out:
#                 COUNTRY Iso3  \
# INFORMYear
# 2015-01-01  Afghanistan  AFG
# 2016-01-01  Afghanistan  AFG
# 2017-01-01  Afghanistan  AFG
# 2018-01-01  Afghanistan  AFG
# 2019-01-01  Afghanistan  AFG
#
#             % of Populations at risk of Plasmodium falciparum malaria  \
# INFORMYear
# 2015-01-01                                           0.872426
# 2016-01-01                                           0.856048
# 2017-01-01                                           0.857293
# 2018-01-01                                           0.857636
# 2019-01-01                                           0.856141
#
#             Access to Health Care  Access to electricity  \
# INFORMYear
# 2015-01-01                    8.9              45.300000
# 2016-01-01                    8.6              37.200000
# 2017-01-01                    8.6              48.949998
# 2018-01-01                    8.3              48.949998
# 2019-01-01                    8.0              47.065439
#
# ...

# %%
# df['INFORMYear'] = pd.to_datetime(df['INFORMYear'], format='%Y')

# %%
df.rename(columns = {'INFORMYear': 'Year', 'COUNTRY':'Country'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1910 entries, 2015-01-01 to 2024-01-01
# Data columns (total 61 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Country                                                                1910 non-null   object
#  1   Iso3                                                                   1910 non-null   object
#  2   % of Populations at risk of Plasmodium falciparum malaria              1910 non-null   float64
#  3   Access to Health Care                                                  1910 non-null   float64
#  4   Access to electricity                                                  1910 non-null   float64
#  5   Access to improved sanitation facilities                               1910 non-null   float64
# ...

# %%
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Years')
plt.ylabel('Risk Indices (0-10)')
plt.plot(df_vlowrisk['INFORM Risk Index'])
plt.title("Countries with 2015-2024 mean very low risk INFORM indices");

# %%
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Years')
plt.ylabel('Risk Indices (0-10)')
plt.plot(df_lowrisk['INFORM Risk Index'])
plt.title("Countries with 2015-2024 very low risk INFORM indices");

# %%
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Years')
plt.ylabel('Risk Indices (0-10)')
plt.plot(df_medrisk['INFORM Risk Index'])
plt.title("Countries with 2015-2024 mean medium risk INFORM indices");

# %%
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Years')
plt.ylabel('Risk Indices (0-10)')
plt.plot(df_highrisk['INFORM Risk Index'])
plt.title("Countries with 2015-2024 mean high risk INFORM indices");

# %%
plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Years')
plt.ylabel('Risk Indices (0-10)')
plt.plot(df_vhighrisk['INFORM Risk Index'])
plt.title("Countries with 2015-2024 mean very high risk INFORM indices");

# %%
df[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
   ]].plot(subplots=True, layout=(2,2));

# %%
df[['% of Populations at risk of Plasmodium falciparum malaria','Adult prevalence of HIV-AIDS',
       'Maternal Mortality Ratio', 'People using at least basic sanitation services (% of population)', 
       'Physicians density', 'Prevalence of undernourishment', 'Public aid per capita',
       'Under-five mortality rate', 'Urban population growth (annual %)','Vets per capita', 'Vulnerable Groups']].plot(subplots=True, layout=(3,4));

# %% [markdown]
# df[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index', '% of Populations at risk of Plasmodium falciparum malaria',
#         'Access to electricity','Adult prevalence of HIV-AIDS', 'Corruption Perception Index', 'GDP per capita',
#        'Gender Inequality Index', 'Government Effectiveness', 'Health expenditure per capita',
#         'Highly Violent Conflict Probability','Internet users', 'Literacy rate, adult total',
#        'Maternal Mortality Ratio', 'Mobile cellular subscriptions', 'Multidimensional Poverty Index',
#        'People using at least basic sanitation services (% of population)', 'Personal remittances, received (% of GDP)',
#        'Physicians density', 'Population ages 0-5 (% of total)', 'Population living in slums (% of urban population)',
#        'Population living in urban areas (%)', 'Prevalence of undernourishment', 'Public aid per capita',
#        'Recent shocks', 'Road density', 'Total affected by Natural Disasters last 3 years (% of total pop)',
#        'Under-five mortality rate', 'Urban population growth (annual %)','Vets per capita', 'Vulnerable Groups']].plot(subplots=True, layout=(20,20));

# %%
# Histogram showing INFORM Index Distribution
# Filter the DataFrame to include only rows for the year 2024

plt.figure(figsize=(8, 6))  # Set the figure size

plt.title("Distribution of Mean INFORM Indices 2015-2024")  # Title for the plot

# Create the histogram plot with custom color and size
sns.histplot(data=df, x="Mean_INFORM_Index", color='darkblue', bins=40) #bins = size (thick/thin) of bars
plt.xlabel("Mean INFORM Risk Index")  # Label for the x-axis
plt.ylabel("Number of Countries")  # Label for the y-axis - not required

plt.show()

# %%
df_vlowrisk = df[(df['Mean_INFORM_Index'] < 2.2)]
df_vlowrisk.shape
# Out:
# (380, 62)

# %%
df_lowrisk = df[df['Mean_INFORM_Index'].between (2.2,3.2)] # greater than or equal to 2.2, to less than 3.1
df_lowrisk.shape
# Out:
# (520, 62)

# %%
df_medrisk = df[df['Mean_INFORM_Index'].between (3.1,4.9)]
df_medrisk.shape
# Out:
# (670, 62)

# %%
df_highrisk = df[df['Mean_INFORM_Index'].between (4.9,7)]
df_highrisk.shape
# Out:
# (310, 62)

# %%
df_vhighrisk = df[df['Mean_INFORM_Index'].between (7,10)]
df_vhighrisk.shape
# Out:
# (70, 62)

# %%
df_vlowrisk[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
         ]].plot(subplots=True, layout=(4,1));

# %%
df_lowrisk[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
         ]].plot(subplots=True, layout=(4,1));

# %%
df_medrisk[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
         ]].plot(subplots=True, layout=(4,1));

# %%
df_highrisk[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
         ]].plot(subplots=True, layout=(4,1));

# %%
df_vhighrisk[["INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index'
         ]].plot(subplots=True, layout=(4,1));

# %% [markdown]
# ### Plotting Autocorrelation

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['INFORM Risk Index'], lag=1)
plt.title('Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000 -0.015505
# t+1 -0.015505  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_vhighrisk['INFORM Risk Index'], lag=1)
plt.title('Very High Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_vhighrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      t-1  t+1
# t-1  NaN  NaN
# t+1  NaN  1.0

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_highrisk['INFORM Risk Index'], lag=1)
plt.title('High Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_highrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000 -0.244656
# t+1 -0.244656  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_medrisk['INFORM Risk Index'], lag=1)
plt.title('Medium Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_medrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000 -0.084724
# t+1 -0.084724  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_lowrisk['INFORM Risk Index'], lag=1)
plt.title('Low Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_lowrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.378198
# t+1  0.378198  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_vlowrisk['INFORM Risk Index'], lag=1)
plt.title('Very Low Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_vlowrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000 -0.113122
# t+1 -0.113122  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df_vhighrisk['INFORM Risk Index'], lag=1)
plt.title('Very High Risk Index & GDP per Capita Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df_vhighrisk['GDP per capita'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      t-1  t+1
# t-1  NaN  NaN
# t+1  NaN  1.0

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['GDP per capita'], lag=1)
plt.title('GDP per Capita & Risk Index Autocorrelation plot')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['INFORM Risk Index'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.024989
# t+1  0.024989  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['INFORM Risk Index'], lag=1)
plt.title('Risk Index vs Adult prevalence of HIV-AIDS')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['Adult prevalence of HIV-AIDS'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.014617
# t+1  0.014617  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['INFORM Risk Index'], lag=1)
plt.title('Risk Index vs % Populations at risk of Plasmodium falciparum malaria')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['% of Populations at risk of Plasmodium falciparum malaria'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.007978
# t+1  0.007978  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['INFORM Risk Index'], lag=1)
plt.title('Risk Index vs % Populations at risk of Plasmodium falciparum malaria')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['% of Populations at risk of Plasmodium falciparum malaria'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000  0.007978
# t+1  0.007978  1.000000

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(12,8))
lag_plot(df['INFORM Risk Index'], lag=1)
plt.title('Risk Index vs Literacy rate, adult total')
plt.grid(True)
plt.legend();

from pandas import DataFrame
from pandas import concat
values = DataFrame(df['Literacy rate, adult total'].values)
dataframe = concat([values.shift(120), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#           t-1       t+1
# t-1  1.000000 -0.003272
# t+1 -0.003272  1.000000

# %%
"INFORM Risk Index", 'Hazard & Exposure Index', 'Lack of Coping Capacity Index','Vulnerability Index', 
'% of Populations at risk of Plasmodium falciparum malaria',
        'Access to electricity','Adult prevalence of HIV-AIDS', 'Corruption Perception Index', 'GDP per capita',
       'Gender Inequality Index', 'Government Effectiveness', 'Health expenditure per capita', 
        'Highly Violent Conflict Probability','Internet users', 'Literacy rate, adult total',
       'Maternal Mortality Ratio', 'Mobile cellular subscriptions', 'Multidimensional Poverty Index',
       'People using at least basic sanitation services (% of population)', 'Personal remittances, received (% of GDP)',
       'Physicians density', 'Population ages 0-5 (% of total)', 'Population living in slums (% of urban population)',
       'Population living in urban areas (%)', 'Prevalence of undernourishment', 'Public aid per capita',
       'Recent shocks', 'Road density', 'Total affected by Natural Disasters last 3 years (% of total pop)',
       'Under-five mortality rate', 'Urban population growth (annual %)','Vets per capita', 'Vulnerable Groups'

# %% [markdown]
# ## Making Overall INFORM Index Prediction with ARIMA model

# %% [markdown]
# AutoRegressive Integrated Moving Average
# https://www.kdnuggets.com/2023/08/times-series-analysis-arima-models-python.html
# https://www.kaggle.com/code/bogdanbaraban/ar-arima-lstm#ARIMA-model
#
#
# - AR (Autoregression): This emphasizes the dependent relationship between an observation and its preceding or ‘lagged’ observations.
# - I (Integrated): To achieve a stationary time series, one that doesn’t exhibit trend or seasonality, differencing is applied. It typically involves subtracting an observation from its preceding observation.
# - MA (Moving Average): This component zeroes in on the relationship between an observation and the residual error from a moving average model based on lagged observations.
#
# The parameters of the ARIMA model are defined as follows:
#
#     p: The lag order, representing the number of lag observations incorporated in the model.
#     d: Degree of differencing, denoting the number of times raw observations undergo differencing.
#     q: Order of moving average, indicating the size of the moving average window.
#
# A linear regression model is constructed including the specified number and type of terms, and the data is prepared by a degree of differencing to make it stationary, i.e. to remove trend and seasonal structures that negatively affect the regression model.
#
# Interestingly, any of these parameters can be set to 0. Such configurations enable the ARIMA model to mimic the functions of simpler models like ARMA, AR, I, or MA.
#
# Adopting an ARIMA model for a time series assumes that the underlying process that generated the observations is an ARIMA process. This may seem obvious but helps to motivate the need to confirm the assumptions of the model in the raw observations and the residual errors of forecasts from the model.
#
#
# https://www.geeksforgeeks.org/python-arima-model-for-time-series-forecasting/
#
# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
#
# https://medium.com/datainc/time-series-analysis-and-forecasting-with-arima-in-python-aa22694b3aaa
#
# https://towardsdatascience.com/machine-learning-part-19-time-series-and-autoregressive-integrated-moving-average-model-arima-c1005347b0d7
#
# https://www.kaggle.com/code/prashant111/arima-model-for-time-series-forecasting
#
# https://www.justintodata.com/arima-models-in-python-time-series-prediction/

# %% [markdown]
# #### Data Preparation:
# - Ensure your data is stationary, or can be made stationary through differencing. This usually involves removing trends and seasonality. Formatting the data for Time Series Model. Time column, variables/features for comparison, no null values in features
#
# #### Model Identification:
# - Determine the parameters of the ARIMA model (p, d, q) through analysis of the autocorrelation function (ACF) and partial autocorrelation function (PACF) plots.
#
# #### Model Estimation:
# - Fit the ARIMA model to the data using techniques like maximum likelihood estimation.
#
# #### Model Diagnostic Checking:
# - Verify that the residuals of the model are white noise. If not, refine the model.
#
#  #### Forecasting:
#  - Finally, use the fitted ARIMA model to make predictions into the future.

# %% [markdown]
# ### Fitting the model to existing data before forecasting

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math


train_data, test_data = df[0:int(len(df)*0.9)], df[int(len(df)*0.9):]


train_arima = train_data['INFORM Risk Index']
test_arima = test_data['INFORM Risk Index']


history = [x for x in train_arima]
y = test_arima
# make first prediction
predictions = list()
model = ARIMA(history, order=(1,1,0))
model_fit = model.fit()
yhat = model_fit.forecast()[0]
predictions.append(yhat)
history.append(y[0])

# %%
# rolling forecasts
for i in range(1, len(y)):
    # predict
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    # invert transformed prediction
    predictions.append(yhat)
    # observation
    obs = y[i]
    history.append(obs)

# %%
# report performance
mse = mean_squared_error(y, predictions)
print('MSE: '+str(mse))
mae = mean_absolute_error(y, predictions)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE: '+str(rmse))
# Out:
# MSE: 0.4162681363635922
# MAE: 0.26827910867201576
# RMSE: 0.6451884502713856

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['INFORM Risk Index'].tail(600), color='green', label = 'Index')
plt.plot(test_data.index, y, color = 'red', label = 'Real index')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted index')
plt.title('Overall Index Prediction')
plt.xlabel('Time')
plt.ylabel('Index')
plt.legend()
plt.grid(True)
plt.savefig('arima_model.pdf')
plt.show()

# %%
train_data, test_data = df_risk3[0:int(len(df_risk3)*0.9)], df_risk3[int(len(df_risk3)*0.9):]

train_arima = train_data['INFORM Risk Index']
test_arima = test_data['INFORM Risk Index']


history = [x for x in train_arima]
y = test_arima
# make first prediction
predictions = list()
model = ARIMA(history, order=(1,1,0))
model_fit = model.fit()
yhat = model_fit.forecast()[0]
predictions.append(yhat)
history.append(y[0])
# Out:
# C:\Users\oakpogheneta\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# rolling forecasts
for i in range(1, len(y)):
    # predict
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    # invert transformed prediction
    predictions.append(yhat)
    # observation
    obs = y[i]
    history.append(obs)

# %%
# report performance
mse = mean_squared_error(y, predictions)
print('MSE: '+str(mse))
mae = mean_absolute_error(y, predictions)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE: '+str(rmse))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['INFORM Risk Index'].tail(600), color='green', label = 'Index')
plt.plot(test_data.index, y, color = 'red', label = 'Real index')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted index')
plt.title('Overall Index Prediction')
plt.xlabel('Time')
plt.ylabel('Index')
plt.legend()
plt.grid(True)
plt.savefig('arima_model.pdf')
plt.show()

# %%
train_data, test_data = df_risk7[0:int(len(df_risk8)*0.9)], df_risk8[int(len(df)*0.9):]

train_arima = train_data['INFORM Risk Index']
test_arima = test_data['INFORM Risk Index']


history = [x for x in train_arima]
y = test_arima
# make first prediction
predictions = list()
model = ARIMA(history, order=(1,1,0))
model_fit = model.fit()
yhat = model_fit.forecast()[0]
predictions.append(yhat)
history.append(y[0])

# %%
# rolling forecasts
for i in range(1, len(y)):
    # predict
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    # invert transformed prediction
    predictions.append(yhat)
    # observation
    obs = y[i]
    history.append(obs)

# %%
# report performance
mse = mean_squared_error(y, predictions)
print('MSE: '+str(mse))
mae = mean_absolute_error(y, predictions)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(y, predictions))
print('RMSE: '+str(rmse))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['INFORM Risk Index'].tail(600), color='green', label = 'Index')
plt.plot(test_data.index, y, color = 'red', label = 'Real index')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted index')
plt.title('Overall Index Prediction')
plt.xlabel('Time')
plt.ylabel('Index')
plt.legend()
plt.grid(True)
plt.savefig('arima_model.pdf')
plt.show()

# %%
sns.scatterplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", hue="sex", style="sex")
