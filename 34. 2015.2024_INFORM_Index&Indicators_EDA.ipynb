# %% [markdown]
# ## 2015-2024 INFORM Select Indeces & Indicators Dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import datetime , calendar

import folium #for mapping

# %%
df = pd.read_csv('2015-2024 All Selected Index_Indicator_df.csv')

# %%
df.head()
# Out:
#   Iso3  2024 INFORM Risk Index  2023 INFORM Risk Index  \
# 0  AFG                     8.1                     8.1
# 1  AGO                     5.2                     5.0
# 2  ARE                     1.7                     1.7
# 3  ARG                     2.9                     2.9
# 4  ARM                     2.9                     2.9
#
#    2022 INFORM Risk Index  2021 INFORM Risk Index  2020 INFORM Risk Index  \
# 0                     8.0                     8.0                     8.1
# 1                     5.0                     5.1                     4.8
# 2                     1.6                     1.7                     1.6
# 3                     2.9                     2.8                     2.7
# 4                     3.2                     5.0                     3.2
#
#    2019 INFORM Risk Index  2018 INFORM Risk Index  2017 INFORM Risk Index  \
# 0                     8.0                     7.8                     7.9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Columns: 291 entries, Iso3 to 2015 Total population
# dtypes: float64(240), int64(50), object(1)
# memory usage: 434.4+ KB

# %%
df1 = pd.read_excel('Country name + Iso.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   COUNTRY  191 non-null    object
#  1   Iso3     191 non-null    object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
df = pd.merge(df, df1, on ='Iso3', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Columns: 292 entries, Iso3 to COUNTRY
# dtypes: float64(240), int64(50), object(2)
# memory usage: 435.8+ KB

# %%
df.head()
# Out:
#   Iso3  2024 INFORM Risk Index  2023 INFORM Risk Index  \
# 0  AFG                     8.1                     8.1
# 1  AGO                     5.2                     5.0
# 2  ARE                     1.7                     1.7
# 3  ARG                     2.9                     2.9
# 4  ARM                     2.9                     2.9
#
#    2022 INFORM Risk Index  2021 INFORM Risk Index  2020 INFORM Risk Index  \
# 0                     8.0                     8.0                     8.1
# 1                     5.0                     5.1                     4.8
# 2                     1.6                     1.7                     1.6
# 3                     2.9                     2.8                     2.7
# 4                     3.2                     5.0                     3.2
#
#    2019 INFORM Risk Index  2018 INFORM Risk Index  2017 INFORM Risk Index  \
# 0                     8.0                     7.8                     7.9
# ...

# %%
import os

# Define the folder path where you want to save the DataFrames
folder_path = '~/Desktop/CodeOp/DSF02/Group Project'

# Construct the file path
file_path = os.path.join(folder_path, f"2015-2024 Selected Index & Indicator Dataframes.csv")

# Save each DataFrame as a separate CSV file in the specified folder
df.to_csv(file_path, index=False)

# %%
df.columns
# Out:
# Index(['Iso3', '2024 INFORM Risk Index', '2023 INFORM Risk Index',
#        '2022 INFORM Risk Index', '2021 INFORM Risk Index',
#        '2020 INFORM Risk Index', '2019 INFORM Risk Index',
#        '2018 INFORM Risk Index', '2017 INFORM Risk Index',
#        '2016 INFORM Risk Index',
#        ...
#        '2023 Total population', '2022 Total population',
#        '2021 Total population', '2020 Total population',
#        '2019 Total population', '2018 Total population',
#        '2017 Total population', '2016 Total population',
#        '2015 Total population', 'COUNTRY'],
#       dtype='object', length=292)

# %%
column_list = list(df.columns)
print(column_list)
# Out:
# ['Iso3', '2024 INFORM Risk Index', '2023 INFORM Risk Index', '2022 INFORM Risk Index', '2021 INFORM Risk Index', '2020 INFORM Risk Index', '2019 INFORM Risk Index', '2018 INFORM Risk Index', '2017 INFORM Risk Index', '2016 INFORM Risk Index', '2015 INFORM Risk Index', '2024 Hazard & Exposure Index', '2023 Hazard & Exposure Index', '2022 Hazard & Exposure Index', '2021 Hazard & Exposure Index', '2020 Hazard & Exposure Index', '2019 Hazard & Exposure Index', '2018 Hazard & Exposure Index', '2017 Hazard & Exposure Index', '2016 Hazard & Exposure Index', '2015 Hazard & Exposure Index', '2024 Vulnerability Index', '2023 Vulnerability Index', '2022 Vulnerability Index', '2021 Vulnerability Index', '2020 Vulnerability Index', '2019 Vulnerability Index', '2018 Vulnerability Index', '2017 Vulnerability Index', '2016 Vulnerability Index', '2015 Vulnerability Index', '2024 Lack of Coping Capacity Index', '2023 Lack of Coping Capacity Index', '2022 Lack of Coping Capacity Index', '2021 Lack of C
# ...

# %%
# Removing Upper or Lower Half of Corr Heatmap

selected_columns = df[['2024 Governance', '2023 Governance', '2022 Governance', '2021 Governance', '2020 Governance', 
                       '2019 Governance', '2018 Governance', '2017 Governance', '2016 Governance', '2015 Governance',
                       '2024 Highly Violent Conflict Probability', '2023 Highly Violent Conflict Probability', '2022 Highly Violent Conflict Probability', '2021 Highly Violent Conflict Probability', '2020 Highly Violent Conflict Probability', 
                       '2019 Highly Violent Conflict Probability', '2018 Highly Violent Conflict Probability', '2017 Highly Violent Conflict Probability', '2016 Highly Violent Conflict Probability', '2015 Highly Violent Conflict Probability',
                       '2024 Mobile cellular subscriptions', '2023 Mobile cellular subscriptions', '2022 Mobile cellular subscriptions', '2021 Mobile cellular subscriptions', '2020 Mobile cellular subscriptions', 
                       '2019 Mobile cellular subscriptions', '2018 Mobile cellular subscriptions', '2017 Mobile cellular subscriptions', '2016 Mobile cellular subscriptions', '2015 Mobile cellular subscriptions',
                       '2024 GDP per capita', '2023 GDP per capita', '2022 GDP per capita', '2021 GDP per capita', '2020 GDP per capita', 
                       '2019 GDP per capita', '2018 GDP per capita', '2017 GDP per capita', '2016 GDP per capita', '2015 GDP per capita', 
                       '2024 Gender Inequality Index', '2023 Gender Inequality Index', '2022 Gender Inequality Index', '2021 Gender Inequality Index', '2020 Gender Inequality Index', 
                       '2019 Gender Inequality Index', '2018 Gender Inequality Index', '2017 Gender Inequality Index', '2016 Gender Inequality Index', '2015 Gender Inequality Index'
                      ]]

correlation_matrix = selected_columns.corr() # Calculate the correlation matrix

mask = 1 - np.tril(np.ones_like(correlation_matrix)) # Create a mask for the upper triangle

# Create a heatmap of the correlation matrix showing only the lower triangle
plt.figure(figsize=(10, 8))
plt.title('INFORM Index Correlation Heatmap - Lower Triangle')
heatmap = sns.heatmap(correlation_matrix, cmap="YlGn", mask=mask) #annot=True adds the numbers to the matrix
plt.show()

# %%
# Removing Upper or Lower Half of Corr Heatmap

selected_columns = df[["2024 INFORM Risk Index", 
                       "2023 INFORM Risk Index", 
                       "2022 INFORM Risk Index", 
                       "2021 INFORM Risk Index", 
                       "2020 INFORM Risk Index", 
                       "2019 INFORM Risk Index", 
                       "2018 INFORM Risk Index", 
                       "2017 INFORM Risk Index", 
                       "2016 INFORM Risk Index", 
                       "2015 INFORM Risk Index",
                       "2024 Total population",
                       "2023 Total population",
                       "2022 Total population",
                       "2021 Total population",
                       "2020 Total population",
                       "2019 Total population", 
                       "2018 Total population", 
                       "2017 Total population",
                       "2016 Total population",
                       "2015 Total population"
                      ]]

correlation_matrix = selected_columns.corr() # Calculate the correlation matrix

mask = 1 - np.tril(np.ones_like(correlation_matrix)) # Create a mask for the upper triangle

# Create a heatmap of the correlation matrix showing only the lower triangle
plt.figure(figsize=(10, 8))
plt.title('INFORM Index Correlation Heatmap - Lower Triangle')
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap="YlGn", mask=mask)
plt.show()

# %%
# Create a correlation heatmap with sequential colours
selected_columns = listings[["price", "number_of_reviews", "review_scores_rating"]]

# Calculate the correlation matrix
correlation_matrix = selected_columns.corr()

# Create a mask for the upper triangle
# mask = 1 - np.tril(np.ones_like(correlation_matrix))

# Create a heatmap of the correlation matrix with a diverging color map
plt.figure(figsize=(10, 8))
plt.title('Price, Review, Rating Correlation Matrix Heatmap with Color Map')
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='PuRd')
plt.show()

# %%
# Scatter plot bill_length_mm and flipper_length_mm with a line of best fit
plt.title('Bill Length vs. Flipper Length')  # Add title
sns.regplot(
    data=penguins,
    x="bill_length_mm",
    y="flipper_length_mm",
    scatter_kws={"color": "green"},  # Set color of the scatter points # kws is an abbreviation for keyword arguments
    line_kws={"color": "red"}  # Set color of the regression line # kws is an abbreviation for keyword arguments
)
plt.show()

# %%
Map = folium.Map()
Map
